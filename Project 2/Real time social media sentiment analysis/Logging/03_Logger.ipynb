# %%
import logging

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s | %(levelname)s | %(message)s"
)

logger = logging.getLogger("SocialMediaPipeline")

print("Logger notebook executed successfully")
# Out:
# Logger notebook executed successfully
